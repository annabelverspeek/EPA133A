# %%
import pandas as pd 

#import the data of the overview

# x toevoegen 
Overview_file = '_overview.xls'
Overview = pd.read_excel(Overview_file)

# Filteren welke wegen langer zijn dan 25 km
filtered_length = Overview[Overview['length'] >= 25]
#print(filtered_length.info)

# import the html file with the road descriptions 
file_path = 'N1.lrps.htm'
df_list = pd.read_html(file_path)
# create a dataframe from the html file, the table is the fourth element in the html list 
df = df_list[4]
# cleaning the dataframe so that the correct rows are taken into account 
df = df.drop(index=0, columns=[df.columns[0], df.columns[-1]])
df.columns = df.iloc[0]
df = df.drop(index=1)
filtered_df = df[df['LRP TYPE'].str.contains('Cross Road|Side Road')]

# Initialize an empty list to store the filtered rows
filtered_rows = []

# Iterate over each row in filtered_length
for index, row in filtered_length.iterrows():
    road_name = row['road']
    # Exclude "N1" road name
    if road_name != "N1":
        # Filter rows in filtered_df where the "Description" column contains the road name
        matching_rows = filtered_df[filtered_df['Description'].str.contains(road_name, case=False)].copy()
        # Add a new column "road name" with the road name for each matching row
        matching_rows['road name'] = road_name
        # Append the matching rows to the list
        filtered_rows.append(matching_rows)

# Concatenate the filtered rows into a single DataFrame
filtered_df = pd.concat(filtered_rows, ignore_index=True)

filtered_df.head(30)
# Out:
# 1     LRP No Road Chainage          LRP TYPE  \
# 4      LRPSb         0.822        Cross Road
# 10   LRP004a         4.175  Side Road, Right
# 14   LRP007a         7.181        Cross Road
# 19   LRP009a         8.763   Side Road, Left
# 30   LRP012c        11.936  Side Road, Right
# 37   LRP016a        15.935  Side Road, Right
# 52   LRP020a        20.044   Side Road, Left
# 85   LRP031a        30.936  Side Road, Right
# 106  LRP038c        38.466  Side Road, Right
# 121  LRP046a        45.322  Side Road, Right
# 122  LRP046b        45.388   Side Road, Left
# 125  LRP047a        47.224  Side Road, Right
# 142  LRP056c        55.477   Side Road, Left
# 152  LRP063a        62.278   Side Road, Left
# 164  LRP070a        69.616   Side Road, Left
# 165  LRP070b        69.638  Side Road, Right
# 177  LRP077a        75.589   Side Road, Left
# 188  LRP084a        81.846   Side Road, Left
# 194  LRP088a        85.897        Cross Road
# 198  LRP089c        87.366        Cross Road
# 207  LRP094a        91.583        Cross Road
# 238  LRP108c       105.879  Side Road, Right
# 275  LRP122a       119.698  Side Road, Right
# 294  LRP130a       128.009  Side Road, Right
# 325  LRP142a       138.869  Side Road, Right
# 327  LRP143a       140.251        Cross Road
# 334  LRP146a       143.034  Side Road, Right
# 339  LRP148a       145.409        Cross Road
# 346  LRP152a       149.289   Side Road, Left
# 347  LRP152b       149.585  Side Road, Right
#
# 1                                          Description Latitude Decimal  \
# 4                              Intersection with Z1101       23.7027778
# 10                           Road to Narayanganj(R111)       23.6938052
# 14            R110,Left to Demra, Right to Narayanganj       23.6979163
# 19                                 Road to Sylhet (N2)       23.7060833
# 30     Right to Syedpur (R113) left to Joydebpur N105)       23.6904163
# 37                             Road to MinanbariZ1061)       23.6604167
# 52   Left to Sonargaon (Z1089) Right to Morgrapara ...       23.6358608
# 85                              Road to Gazara (Z1063)       23.5590278
# 106                             Road to Matlab (Z1062)       23.5314716
# 121                              Z1402, road to Pennai       23.5307493
# 122                               Z1053, Road to Homna        23.530666
# 125                                              Z1044       23.5306938
# 142                        Z1042, road to Bancharampur       23.5126667
# 152                         Z1017, Road to Companiganj       23.5043333
# 164                           Road to Debiduar (Z1008)       23.4894441
# 165                             Road to Jhalam (Z1022)       23.4893886
# 177  Road to Khangsanagar (Z1219) left road to Baru...       23.4815271
# 188                         Road to Brahmanbaria(N102)       23.4789716
# 194                                   Cross road Z1029           23.459
# 198                              Cross Road with Z1052       23.4469441
# 207                  Left to Comilla Right to Noakhali       23.4191382
# 238                         Road to Harishchar (Z1046)       23.3347219
# 275                           Road to Bangadda (Z1045)        23.221416
# 294                          Road to Nangolhat (Z1048)       23.1496941
# 325                           Road to Karerhat (Z1031)       23.0614722
# 327                                              Z1031       23.0479441
# 334                             Road to Biroli (Z1030)       23.0248327
# 339                             Intersection with N104       23.0095556
# 346                          Road to Feni Town (Z1034)       22.9877774
# 347                           Road to Sonagazi (Z1034)       22.9858886
#
# 1   Longitued Decimal
# 4          90.4504722
# 10         90.4805271
# 14         90.5092778
# 19         90.5215271
# 30          90.546583
# 37         90.5671104
# 52         90.5948052
# 85         90.6559444
# 106        90.7172216
# 121        90.7816104
# 122        90.7821938
# 125        90.7924441
# 142         90.871416
# 152        90.9354719
# 164        91.0033056
# 165        91.0034722
# 177        91.0590278
# 188         91.118166
# 194         91.142333
# 198        91.1481386
# 207        91.1721938
# 238         91.271166
# 275        91.3137222
# 294        91.3254993
# 325        91.3616667
# 327        91.3651389
# 334        91.3655278
# 339        91.3813604
# 346             91.41
# 347        91.4120556
